# %% [markdown]
# Course 7
# Coronavirus disease 2019 (COVID-19) is an infectious disease caused by severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). The disease was first identified in 2019 in Wuhan, China, and has since spread globally, resulting in the 2019–20 coronavirus pandemic. Common symptoms include fever, cough and shortness of breath. Muscle pain, sputum production and sore throat are less common. The rate of deaths per number of diagnosed cases is on average 3.4%, ranging from 0.2% in those less than 20 to approximately 15% in those over 80 years old.
# Data Source (Date wise) : 2019 Novel Coronavirus COVID-19 (2019-nCoV) Data Repository by Johns Hopkins CSSE
# Data Source:

# %%
import pandas as pd
path = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/08-19-2021.csv'
df= pd.read_csv(path)
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-08-20 04:21:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-08-20 04:21:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-08-20 04:21:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-08-20 04:21:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-08-20 04:21:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     152411    7047        NaN     NaN  Afghanistan
# 1  20.168300     137597    2473        NaN     NaN      Albania
# 2   1.659600     190078    4929        NaN     NaN      Algeria
# 3   1.521800      14981     129        NaN     NaN      Andorra
# 4  17.873900      45325    1133        NaN     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     391.516813             4.623682
# 1    4781.326013             1.797278
# ...

# %%
df.isna().sum()
# Out:
# FIPS                    748
# Admin2                  743
# Province_State          179
# Country_Region            0
# Last_Update               0
# Lat                      90
# Long_                    90
# Confirmed                 0
# Deaths                    0
# Recovered              3986
# Active                 3986
# Combined_Key              0
# Incident_Rate            90
# Case_Fatality_Ratio      42
# dtype: int64

# %%
import pandas as pd
import numpy as np

df= pd.read_csv(path)
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-08-20 04:21:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-08-20 04:21:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-08-20 04:21:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-08-20 04:21:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-08-20 04:21:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     152411    7047        NaN     NaN  Afghanistan
# 1  20.168300     137597    2473        NaN     NaN      Albania
# 2   1.659600     190078    4929        NaN     NaN      Algeria
# 3   1.521800      14981     129        NaN     NaN      Andorra
# 4  17.873900      45325    1133        NaN     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     391.516813             4.623682
# 1    4781.326013             1.797278
# ...

# %% [markdown]
# Field description
# •	Province/State: China - province name; US/Canada/Australia/ - city name, state/province name; Others - name of the event (e.g., "Diamond Princess" cruise ship); other countries - blank.
# •	Country/Region: country/region name conforming to WHO (will be updated).
# •	Last Update: MM/DD/YYYY HH:mm (24 hour format, in UTC).
# •	Confirmed: the number of confirmed cases. For Hubei Province: from Feb 13 (GMT +8), we report both clinically diagnosed and lab-confirmed cases. For lab-confirmed cases only (Before Feb 17), please refer to who_covid_19_situation_reports. For Italy, diagnosis standard might be changed since Feb 27 to "slow the growth of new case numbers." (Source)
# •	Deaths: the number of deaths.
# •	Recovered: the number of recovered cases.
#
#
# Using above dataset we have created some exercises on COVID-19 (Spread of the novel coronavirus, Analysis, Visualization, Prediction & Comparisons.
#
#
# Please use jupyter lab on your local computer to solve all the questions written below. Each group needs to share one ipynb file.

# %% [markdown]
# 1.	Write a Python program to display first 5 rows from COVID-19 dataset. Also print the dataset information and check the missing values.

# %% [markdown]
# 2.	Write a python program to replace all the missing values with “Tobefound” for province column.

# %% [markdown]
# 3.	Normalize the values for “Recovered” column as per the z-score.

# %% [markdown]
# 4.	Create bin values for “Recovered” column in the data set.

# %% [markdown]
# 5.	Write a Python program to get the maximum number of confirmed, deaths, recovered and active cases of Novel Coronavirus (COVID-19) Country wise.

# %% [markdown]
# 6.	 Write a Python program to get the total number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise

# %% [markdown]
# 7.	Write a Python program to get the country wise (country name taken as input from user) cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19).

# %% [markdown]
# 8.	Write a Python program to get the country wise deaths cases of Novel Coronavirus (COVID-19).

# %% [markdown]
# 9.	Write a Python program to list countries with no cases of Novel Coronavirus (COVID-19) recovered.

# %% [markdown]
# 10.	 Write a Python program to list countries where all cases of Novel Coronavirus (COVID-19) died.

# %% [markdown]
# 11.	 Write a Python program to list countries with all cases of Novel Coronavirus (COVID-19) recovered.

# %% [markdown]
# 12.	 Write a Python program to get the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19).

# %% [markdown]
# 13.	Write a Python program to create a plot (lines) of total deaths, confirmed, recovered and active cases Country wise where deaths greater than 150.

# %%
### Q1: Write a Python program to display first 5 rows from COVID-19 dataset. Also print the dataset information and check the missing values.
#Write a python program to replace all the missing values with “Tobefound” for province column.
#Normalize the values for “Recovered” column as per the z-score.
#Create bin values for “Recovered” column in the data set.
#Write a Python program to get the maximum number of confirmed, deaths, recovered and active cases of Novel Coronavirus (COVID-19) Country wise.
#Write a Python program to get the total number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise
#Write a Python program to get the country wise (country name taken as input from user) cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19).
#Write a Python program to get the country wise deaths cases of Novel Coronavirus (COVID-19).
#Write a Python program to list countries with no cases of Novel Coronavirus (COVID-19) recovered.
#Write a Python program to list countries where all cases of Novel Coronavirus (COVID-19) died.
#Write a Python program to list countries with all cases of Novel Coronavirus (COVID-19) recovered.
#Write a Python program to get the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19).
#Write a Python program to create a plot (lines) of total deaths, confirmed, recovered and active cases Country wise where deaths greater than 150.

# %%
### Q1: Write a Python program to display first 5 rows from COVID-19 dataset. Also print the dataset information and check the missing values.
df.head(5)
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-08-20 04:21:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-08-20 04:21:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-08-20 04:21:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-08-20 04:21:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-08-20 04:21:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     152411    7047        NaN     NaN  Afghanistan
# 1  20.168300     137597    2473        NaN     NaN      Albania
# 2   1.659600     190078    4929        NaN     NaN      Algeria
# 3   1.521800      14981     129        NaN     NaN      Andorra
# 4  17.873900      45325    1133        NaN     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     391.516813             4.623682
# 1    4781.326013             1.797278
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3266 non-null   float64
#  1   Admin2               3271 non-null   object
#  2   Province_State       3835 non-null   object
#  3   Country_Region       4014 non-null   object
#  4   Last_Update          4014 non-null   object
#  5   Lat                  3924 non-null   float64
#  6   Long_                3924 non-null   float64
#  7   Confirmed            4014 non-null   int64
#  8   Deaths               4014 non-null   int64
#  9   Recovered            28 non-null     float64
#  10  Active               28 non-null     float64
#  11  Combined_Key         4014 non-null   object
#  12  Incident_Rate        3924 non-null   float64
#  13  Case_Fatality_Ratio  3972 non-null   float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 439.2+ KB

# %%
df.isna().sum()
# Out:
# FIPS                    748
# Admin2                  743
# Province_State          179
# Country_Region            0
# Last_Update               0
# Lat                      90
# Long_                    90
# Confirmed                 0
# Deaths                    0
# Recovered              3986
# Active                 3986
# Combined_Key              0
# Incident_Rate            90
# Case_Fatality_Ratio      42
# dtype: int64

# %%
### Q2: Write a python program to replace all the missing values with “Tobefound” for province column.
import numpy as np
df['Province_State'].replace(np.nan, 'Tobefound', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3266 non-null   float64
#  1   Admin2               3271 non-null   object
#  2   Province_State       4014 non-null   object
#  3   Country_Region       4014 non-null   object
#  4   Last_Update          4014 non-null   object
#  5   Lat                  3924 non-null   float64
#  6   Long_                3924 non-null   float64
#  7   Confirmed            4014 non-null   int64
#  8   Deaths               4014 non-null   int64
#  9   Recovered            28 non-null     float64
#  10  Active               28 non-null     float64
#  11  Combined_Key         4014 non-null   object
#  12  Incident_Rate        3924 non-null   float64
#  13  Case_Fatality_Ratio  3972 non-null   float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 439.2+ KB
# ...

# %%
### Q3: Normalize the values for “Recovered” column as per the z-score.
import pandas as pd
from scipy.stats import zscore

# %%
df['Recovered_zscore'] = zscore(df['Recovered'], nan_policy='omit')
df.head(20)
# Out:
#     FIPS Admin2                Province_State       Country_Region  \
# 0    NaN    NaN                     Tobefound          Afghanistan
# 1    NaN    NaN                     Tobefound              Albania
# 2    NaN    NaN                     Tobefound              Algeria
# 3    NaN    NaN                     Tobefound              Andorra
# 4    NaN    NaN                     Tobefound               Angola
# 5    NaN    NaN                     Tobefound  Antigua and Barbuda
# 6    NaN    NaN                     Tobefound            Argentina
# 7    NaN    NaN                     Tobefound              Armenia
# 8    NaN    NaN  Australian Capital Territory            Australia
# 9    NaN    NaN               New South Wales            Australia
# 10   NaN    NaN            Northern Territory            Australia
# 11   NaN    NaN                    Queensland            Australia
# 12   NaN    NaN               South Australia            Australia
# ...

# %%
# Q4: Create bin values for “Recovered” column in the data set.
import numpy as np
bins = np.linspace(df["Recovered"].min(), df["Recovered"].max(), 4)
print(bins)
# Out:
# [     0.         147024.33333333 294048.66666667 441073.        ]

# %%
# Q5: Write a Python program to get the maximum number of confirmed, deaths, recovered and active cases of Novel Coronavirus (COVID-19) Country wise.
country_max = df.groupby('Country_Region')[['Confirmed', 'Deaths', 'Recovered', 'Active']].max()
print(country_max)
# Out:
#                       Confirmed  Deaths  Recovered  Active
# Country_Region
# Afghanistan              152411    7047        NaN     NaN
# Albania                  137597    2473        NaN     NaN
# Algeria                  190078    4929        NaN     NaN
# Andorra                   14981     129        NaN     NaN
# Angola                    45325    1133        NaN     NaN
# ...                         ...     ...        ...     ...
# West Bank and Gaza       323582    3628        NaN     NaN
# Winter Olympics 2022          0       0        0.0     0.0
# Yemen                      7407    1414        NaN     NaN
# Zambia                   203553    3564        NaN     NaN
# Zimbabwe                 121902    4198        NaN     NaN
#
# [201 rows x 4 columns]

# %%
### Q6: Write a Python program to get the total number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise
df1=df[['Province_State', 'Confirmed', 'Deaths', 'Recovered']]
df1.head()
# Out:
#   Province_State  Confirmed  Deaths  Recovered
# 0      Tobefound     152411    7047        NaN
# 1      Tobefound     137597    2473        NaN
# 2      Tobefound     190078    4929        NaN
# 3      Tobefound      14981     129        NaN
# 4      Tobefound      45325    1133        NaN

# %%
###Q7: Write a Python program to get the country wise (country name taken as input from user) cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19).
#country = input("Select country:")
#df2=df[df['Country_Region']==country][['Confirmed', 'Deaths', 'Recovered','Country_Region']]
#df3=df2.groupby('Country_Region')
#df3.head()

country = input("Select country:")
df2=df[df['Country_Region']==country]
df3=df2.groupby('Country_Region')[['Confirmed', 'Deaths', 'Recovered']].sum()
df3.head()
# Out:
# Select country: Australia
#                 Confirmed  Deaths  Recovered
# Country_Region
# Australia           42228     976        0.0

# %%
### Q8: Write a Python program to get the country wise deaths cases of Novel Coronavirus (COVID-19).
country = input("Select country:")
df4=df[df['Country_Region']==country]
df5=df4.groupby('Country_Region')[['Confirmed', 'Deaths', 'Recovered']].sum()
df5.loc[country, 'Deaths']
# Out:
# Select country: China
# 4848

# %%
### Q9:Write a Python program to list countries with no cases of Novel Coronavirus (COVID-19) recovered.
df['Recovered'].replace(np.nan, 0, inplace=True) 
df6=df[(df['Recovered']==0)&(df['Confirmed']>0)].groupby('Country_Region').sum()
df6.head(10)
# Out:
# C:\Users\vieta\AppData\Local\Temp\ipykernel_5172\1660918349.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Recovered'].replace(np.nan, 0, inplace=True)
#                      FIPS Admin2  \
# Country_Region
# Afghanistan           0.0      0
# Albania               0.0      0
# Algeria               0.0      0
# Andorra               0.0      0
# Angola                0.0      0
# Antigua and Barbuda   0.0      0
# Argentina             0.0      0
# Armenia               0.0      0
# ...

# %%
### Q10: Write a Python program to list countries where all cases of Novel Coronavirus (COVID-19) died.
df7 = df[(df['Confirmed'] == df['Deaths']) & (df['Confirmed'] > 0)].groupby('Country_Region')
df7.head()
# Out:
# Empty DataFrame
# Columns: [FIPS, Admin2, Province_State, Country_Region, Last_Update, Lat, Long_, Confirmed, Deaths, Recovered, Active, Combined_Key, Incident_Rate, Case_Fatality_Ratio, Recovered_zscore]
# Index: []

# %%
### Q11: Write a Python program to list countries with all cases of Novel Coronavirus (COVID-19) recovered.
df8 = df[(df['Confirmed'] == df['Recovered']) & (df['Confirmed'] > 0)].groupby('Country_Region')
df8.head()
# Out:
# Empty DataFrame
# Columns: [FIPS, Admin2, Province_State, Country_Region, Last_Update, Lat, Long_, Confirmed, Deaths, Recovered, Active, Combined_Key, Incident_Rate, Case_Fatality_Ratio, Recovered_zscore]
# Index: []

# %%
### Q12:Write a Python program to get the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19).
df9 = df.groupby('Country_Region')[['Last_Update','Confirmed', 'Deaths', 'Recovered']].sum()
df_sorted = df9.sort_values(by=['Confirmed','Deaths', 'Recovered'], ascending=False)
df_sorted.head(10)
# Out:
#                                                       Last_Update  Confirmed  \
# Country_Region
# US              2021-08-20 04:21:332021-08-20 04:21:332021-08-...   37513090
# India           2021-08-20 04:21:332021-08-20 04:21:332021-08-...   32358829
# Brazil          2021-08-20 04:21:332021-08-20 04:21:332021-08-...   20501738
# France          2021-08-20 04:21:332021-08-20 04:21:332021-08-...    6637417
# Russia          2021-08-20 04:21:332021-08-20 04:21:332021-08-...    6592705
# United Kingdom  2021-08-20 04:21:332021-08-20 04:21:332021-08-...    6422475
# Turkey                                        2021-08-20 04:21:33    6157772
# Argentina                                     2021-08-20 04:21:33    5116803
# Colombia        2021-08-20 04:21:332021-08-20 04:21:332021-08-...    4880516
# Spain           2021-08-20 04:21:332021-08-20 04:21:332021-08-...    4758003
#
#                 Deaths  Recovered
# Country_Region
# US              623088        0.0
# ...

# %%
### Q13: Write a Python program to create a plot (lines) of total deaths, confirmed, recovered and active cases Country wise where deaths greater than 150.

import matplotlib.pyplot as plt

# Group data by country and sum deaths, confirmed, recovered, and active cases
r_data = df[['Country_Region','Deaths', 'Confirmed', 'Recovered', 'Active']].groupby(['Country_Region']).sum().reset_index()

# Filter countries with deaths greater than 150
r_data = r_data[r_data['Deaths'] > 150]

# Create the line plot
plt.figure(figsize=(15, 5))
plt.plot(r_data['Country_Region'], r_data['Deaths'], color='red', label='Deaths')
plt.plot(r_data['Country_Region'], r_data['Confirmed'], color='green', label='Confirmed')
